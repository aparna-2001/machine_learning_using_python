# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/machine_learning_using_python/blob/main/Machine_Learning_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# numpy

import numpy as np

#creating a numpy array
a = np.arange(10)
b = np.arange(0,10,2)
c = np.random.random(4)
d = np.random.random((2,3))
e = np.zeros(5)
f = np.zeros((2,3))
g = np.full((3,3),5)
h = np.eye(3)
i = [1,2,3,4,5]
j = np.array(i)


#print(b)
#print(a)
#print(c)
#print(d)
#print(e)
#print(f)
#print(g)
#print(h)
#print(j)
# Out:
# [1 2 3 4 5]
