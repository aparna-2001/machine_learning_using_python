# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/machine_learning_using_python/blob/main/scikit_learn_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

data = datasets.load_iris()


#displaying only data
print(data.data)

#complete description of the data
print(data.DESCR)


#print(data.feature_names)
#print(data.target)
#print(data.target_names)

data_frame = pd.DataFrame(data.data)
print(data_frame)
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
#creating my own data points
  #linearly distributed data

# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression, make_blobs

x, y = make_regression(n_samples = 100, n_features = 1, noise = 5.4)
plt.scatter(x,y)
